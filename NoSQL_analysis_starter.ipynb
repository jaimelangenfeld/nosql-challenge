# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
establishments.find_one()
# Out:
# {'_id': ObjectId('6594cb0682c96c4ef0bede5c'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1, 'latitude': 51},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"There are {count} establishments with a hygiene score of 20.")
# Out:
# There are 41 establishments with a hygiene score of 20.

# %%
# Display the first document in the results using pprint
establishments.find_one(query)
# Out:
# {'_id': ObjectId('6594cb0782c96c4ef0bef98d'),
#  'FHRSID': 110681,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '4029',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'PostCode': 'BN21 1BU',
#  'Phone': '',
#  'RatingValue': '0',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2021-09-23T00:00:00',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0, 'latitude': 50},
#  'RightToReply': '',
#  'Distance': 4613.888288172291,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/110681'}]}

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Convert the result to a Pandas DataFrame
results = establishments.find(query)
hygiene_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
hygiene_rows= hygiene_df['_id'].count()
print(f'There are {hygiene_rows} rows in the DataFrame.')


# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# There are 33 rows in the DataFrame.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 11
#       7 print(f'There are {hygiene_rows} rows in the DataFrame.')
#      10 # Display the first 10 rows of the DataFrame
# ---> 11 df.head(10)
#
# NameError: name 'df' is not defined

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName': {'$regex' : 'London'} , 'RatingValue': {'$gte' : '4'}}
establishments.count_documents(query)

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"There are {count} establishments in London that have a RatingValue greater than or equal to 4.")

# Display the first document in the results using pprint

pprint(establishments.find_one(query))
# Out:
# There are 33 establishments in London that have a RatingValue greater than or equal to 4.
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594cb0782c96c4ef0bf13a7'),
#  'geocode': {'latitude': 51, 'longitude': 0},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
df2 = pd.DataFrame(establishments.find(query))

# Display the number of rows in the DataFrame
print(f"There are {len(df2)} rows in this DataFrame.")

# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# There are 33 rows in this DataFrame.
#                         _id   FHRSID  ChangesByServerID  \
# 0  6594cb0782c96c4ef0bef98d   110681                  0
# 1  6594cb0782c96c4ef0befd0d   612039                  0
# 2  6594cb0782c96c4ef0bf001c   730933                  0
# 3  6594cb0782c96c4ef0bf0207   172735                  0
# 4  6594cb0782c96c4ef0bf0215   172953                  0
# 5  6594cb0782c96c4ef0bf0bb6   512854                  0
# 6  6594cb0782c96c4ef0bf0dd8  1537089                  0
# 7  6594cb0782c96c4ef0bf22ff   155648                  0
# 8  6594cb0782c96c4ef0bf2745  1012883                  0
# 9  6594cb0782c96c4ef0bf2f55   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                             geocode RightToReply     Distance  \
# 0  {'longitude': 0, 'latitude': 50}               4613.888288
# 1  {'longitude': 1, 'latitude': 51}               4617.965824
# 2  {'longitude': 1, 'latitude': 51}               4619.656144
# 3  {'longitude': 0, 'latitude': 50}               4620.421725
# 4  {'longitude': 0, 'latitude': 50}               4620.437179
# 5  {'longitude': 0, 'latitude': 51}               4625.565258
# 6  {'longitude': 0, 'latitude': 51}               4626.200132
# 7  {'longitude': 0, 'latitude': 51}               4632.276890
# 8  {'longitude': 0, 'latitude': 51}               4633.934041
# 9  {'longitude': 0, 'latitude': 51}               4636.552523
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 6            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 7            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 8            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 9            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
pprint(establishments.find_one({'BusinessName': 'Penang Flavours'}, {'geocode.latitude', 'geocode.longitude'}))
# Out:
# {'_id': ObjectId('6594d207ef96766f42394e2f'),
#  'geocode': {'latitude': 51, 'longitude': 0}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51
longitude = 0

query = {'RatingValue': '5', 
         'geocode.latitude': {'$lte': (latitude + degree_search), '$gte': (latitude - degree_search)}, 
         'geocode.longitude': {'$lte': (longitude + degree_search), '$gte': (longitude - degree_search)} 
         }
sort =  [('scores.Hygiene', 1)]

# Print the results
for result in establishments.find(query).sort(sort).limit(5):
    pprint(result)
# Out:
# {'AddressLine1': '131 Church Road',
#  'AddressLine2': 'Willesborough',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Willesborough Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4604.594395993568,
#  'FHRSID': 265140,
#  'LocalAuthorityBusinessID': 'PI/000042596',
#  'LocalAuthorityCode': '179',
#  'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#  'LocalAuthorityName': 'Ashford',
#  'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN24 0JQ',
#  'RatingDate': '2022-03-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594cb0682c96c4ef0beebdd'),
#  'geocode': {'latitude': 51, 'longitude': 0},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/265140',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': 'Ashford Market',
#  'AddressLine2': 'Monument Way',
#  'AddressLine3': 'Sevington',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Stock Pot',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4604.521492899895,
#  'FHRSID': 264566,
#  'LocalAuthorityBusinessID': 'PI/000016780',
#  'LocalAuthorityCode': '179',
#  'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#  'LocalAuthorityName': 'Ashford',
#  'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN24 0HB',
#  'RatingDate': '2022-07-28T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594cb0682c96c4ef0beebb7'),
#  'geocode': {'latitude': 51, 'longitude': 0},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/264566',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': 'Tesco Stores Ltd',
#  'AddressLine2': 'Moat Field Meadow',
#  'AddressLine3': 'Kingsnorth',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Tesco',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'ChangesByServerID': 0,
#  'Distance': 4605.29746187518,
#  'FHRSID': 265245,
#  'LocalAuthorityBusinessID': 'PI/000020943',
#  'LocalAuthorityCode': '179',
#  'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#  'LocalAuthorityName': 'Ashford',
#  'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN23 3LU',
#  'RatingDate': '2021-11-29T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594cb0682c96c4ef0beecdd'),
#  'geocode': {'latitude': 51, 'longitude': 0},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/265245',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': '63 Gladstone Road',
#  'AddressLine2': 'Willesborough',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Londis',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4604.7422520200425,
#  'FHRSID': 1089091,
#  'LocalAuthorityBusinessID': 'PI/000094239',
#  'LocalAuthorityCode': '179',
#  'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#  'LocalAuthorityName': 'Ashford',
#  'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN24 0BZ',
#  'RatingDate': '2021-10-15T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594cb0682c96c4ef0beebea'),
#  'geocode': {'latitude': 51, 'longitude': 0},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1089091',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': 'William Harvey Hospital',
#  'AddressLine2': 'Kennington Road',
#  'AddressLine3': 'Willesborough',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Costa Coffee Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4604.112499220073,
#  'FHRSID': 516184,
#  'LocalAuthorityBusinessID': 'PI/000047600',
#  'LocalAuthorityCode': '179',
#  'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#  'LocalAuthorityName': 'Ashford',
#  'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN24 0LZ',
#  'RatingDate': '2021-12-08T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6594cb0682c96c4ef0beeb65'),
#  'geocode': {'latitude': 51, 'longitude': 0},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/516184',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}

# %%
# Convert result to Pandas DataFrame
pd.DataFrame(establishments.find(query).sort(sort).limit(10))
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6594cb0682c96c4ef0beecdd   265245                  0
# 1  6594cb0682c96c4ef0beebea  1089091                  0
# 2  6594cb0782c96c4ef0bef06d   265539                  0
# 3  6594cb0682c96c4ef0beeed4  1450663                  0
# 4  6594cb0682c96c4ef0beebb7   264566                  0
# 5  6594cb0782c96c4ef0beef7a   735070                  0
# 6  6594cb0782c96c4ef0bef14a  1250780                  0
# 7  6594cb0782c96c4ef0bef07b   265094                  0
# 8  6594cb0682c96c4ef0beebdd   265140                  0
# 9  6594cb0682c96c4ef0beeb65   516184                  0
#
#   LocalAuthorityBusinessID                     BusinessName  \
# 0             PI/000020943                            Tesco
# 1             PI/000094239                           Londis
# 2             PI/000021146             Pizza Hut Restaurant
# 3             PI/000100570                Ashford Peri Peri
# 4             PI/000016780                    The Stock Pot
# 5             PI/000087726                        Starbucks
# 6             PI/000098474  The Old Post Office Coffee Shop
# 7             PI/000034389     Towers Tiny Tots Day Nursery
# 8             PI/000042596               Willesborough Cafe
# 9             PI/000047600                Costa Coffee Cafe
#
#                             BusinessType  BusinessTypeID  \
# 0  Retailers - supermarkets/hypermarkets            7840
# 1                      Retailers - other            4613
# 2                Restaurant/Cafe/Canteen               1
# 3                 Takeaway/sandwich shop            7844
# 4                Restaurant/Cafe/Canteen               1
# 5                Restaurant/Cafe/Canteen               1
# 6                Restaurant/Cafe/Canteen               1
# 7                        Caring Premises               5
# 8                Restaurant/Cafe/Canteen               1
# 9                Restaurant/Cafe/Canteen               1
#
#               AddressLine1         AddressLine2   AddressLine3  ...  \
# 0         Tesco Stores Ltd    Moat Field Meadow     Kingsnorth  ...
# 1        63 Gladstone Road        Willesborough           Kent  ...
# 2   Unit 4 Rutherford Road  Eureka Leisure Park        Ashford  ...
# 3           15 High Street              Ashford           Kent  ...
# 4           Ashford Market         Monument Way      Sevington  ...
# 5        89-91 High Street              Ashford           Kent  ...
# 6            13 Front Road           Woodchurch           Kent  ...
# 7            Towers School       Faversham Road     Kennington  ...
# 8          131 Church Road        Willesborough           Kent  ...
# 9  William Harvey Hospital      Kennington Road  Willesborough  ...
#
#        LocalAuthorityWebSite LocalAuthorityEmailAddress  \
# 0  http://www.ashford.gov.uk   envhealth@ashford.gov.uk
# 1  http://www.ashford.gov.uk   envhealth@ashford.gov.uk
# 2  http://www.ashford.gov.uk   envhealth@ashford.gov.uk
# 3  http://www.ashford.gov.uk   envhealth@ashford.gov.uk
# 4  http://www.ashford.gov.uk   envhealth@ashford.gov.uk
# 5  http://www.ashford.gov.uk   envhealth@ashford.gov.uk
# 6  http://www.ashford.gov.uk   envhealth@ashford.gov.uk
# 7  http://www.ashford.gov.uk   envhealth@ashford.gov.uk
# 8  http://www.ashford.gov.uk   envhealth@ashford.gov.uk
# 9  http://www.ashford.gov.uk   envhealth@ashford.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 1  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 2  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 3  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 4  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 5  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 6  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 7  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 8  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 9  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
#
#                             geocode RightToReply     Distance  \
# 0  {'longitude': 0, 'latitude': 51}               4605.297462
# 1  {'longitude': 0, 'latitude': 51}               4604.742252
# 2  {'longitude': 0, 'latitude': 51}               4606.481982
# 3  {'longitude': 0, 'latitude': 51}               4605.900378
# 4  {'longitude': 0, 'latitude': 51}               4604.521493
# 5  {'longitude': 0, 'latitude': 51}               4606.046577
# 6  {'longitude': 0, 'latitude': 51}               4607.054640
# 7  {'longitude': 0, 'latitude': 51}               4606.498269
# 8  {'longitude': 0, 'latitude': 51}               4604.594396
# 9  {'longitude': 0, 'latitude': 51}               4604.112499
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 6            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 7            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 8            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 9            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'https://api.ratings....
# 8  [{'rel': 'self', 'href': 'https://api.ratings....
# 9  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match_query = {'$match': {'scores.Hygiene': 0}}
group_query = {'$group': {'_id': '$LocalAuthorityName', 
                          'count': {'$sum': 1}
                         }
              }
sort_query = {'$sort': {'count': -1}}

pipeline = [match_query, group_query, sort_query]

results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(f"There are {len(results)} documents in the result.")

# Print the first 10 results
pprint(results[0:10])
# Out:
# There are 55 documents in the result.
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
agg_df = pd.json_normalize(results)

# Display the number of rows in the DataFrame
print(f"There are {len(agg_df)} rows in the DataFrame.")

# Display the first 10 rows of the DataFrame
agg_df.head(10)
# Out:
# There are 55 rows in the DataFrame.
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
